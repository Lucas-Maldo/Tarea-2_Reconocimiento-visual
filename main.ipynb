# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Training

# %%
# !python train.py -config look.ini -model RESNET -gpu 0
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 22ms/step
# Iteracion:  930
# ...
# 1/1 [==============================] - 0s 23ms/step
# Iteracion:  931
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  932
# ...
# 1/1 [==============================] - 0s 18ms/step
# Iteracion:  933
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  934
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  935
# ...
# 1/1 [==============================] - 0s 18ms/step
# Iteracion:  936
# ...
# 1/1 [==============================] - 0s 20ms/step
# Iteracion:  937
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  938
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  939
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  940
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  941
# ...
# 1/1 [==============================] - 0s 17ms/step
# Iteracion:  942
# ...

# %% [markdown]
# #Testing

# %%
# !nvidia-smi
# Out:
# Mon Oct  2 01:55:55 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0    31W /  70W |      0MiB / 15360MiB |     83%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
